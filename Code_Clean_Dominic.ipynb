# %%
import pandas as pd
import numpy as np
from supervised.automl import AutoML
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ## DF Original

# %%
df_canada = pd.read_csv('canada.csv')
df_canada.head()
# Out:
#          date  QUALITY_FLAG        cid industry_raw E_TTM_period_date  \
# 0  2002-01-03          True  SP-065996          NaN        2001-10-31
# 1  2002-01-08          True  SP-002396          NaN        2001-09-30
# 2  2002-01-08          True  SP-006704          NaN        2001-09-30
# 3  2002-01-08          True  SP-008644          NaN        2001-09-30
# 4  2002-01-08          True  SP-013994          NaN        2001-09-30
#
#    E_TTM_ammor_intangibles  E_TTM_asset_writedown  E_TTM_assets_gro_five  \
# 0                    0.000                    0.0                    0.0
# 1                    3.078                    0.0                    0.0
# 2                    0.000                    0.0                    0.0
# 3                    0.000                    0.0                    0.0
# 4                    0.000                    0.0                    0.0
#
#    E_TTM_capex  E_TTM_cash_acquisitions  ...  E_G_cost_debt  E_G_cash_ratio  \
# 0   -12.738000                   -3.336  ...      -0.036902        2.309257
# 1   -20.889000                  -68.220  ...      -0.103778        0.000000
# 2   -17.971623                    0.000  ...      -0.036358        2.451612
# 3   -34.700000                    0.000  ...      -0.117333        0.878049
# 4 -1403.000000                 -133.000  ...      -0.078051        0.000000
#
#    E_G_ebitda_cov  E_G_ret_on_asset  E_G_ret_on_inv_cap  E_G_net_to_cash  \
# 0     -165.453488          0.130018            0.101871        -0.068216
# 1       -2.685925          0.071119            0.067430        -0.004881
# 2        2.262460         -0.069781           -0.039238        -0.045993
# 3       -4.852273         -0.169833           -0.155712        -0.316372
# 4      -14.569697          0.109798            0.078497        -0.157934
#
#    E_G_perm_assets_ratio  return_1q  target_net_income  target_cash_operations
# 0               0.414230        NaN          -5.548000               -5.809000
# 1               0.595752        NaN           6.114000              -11.388000
# 2               0.775432        NaN           8.957867               -1.346965
# 3               0.773996        NaN          71.200000               -9.400000
# 4               0.921832        NaN        -165.000000             -419.000000
#
# [5 rows x 664 columns]

# %% [markdown]
# ## Copie du DF Original - sera envoyé à la fonciton

# %%
df_model = df_canada.copy()

df_model['date'] = pd.to_datetime(df_model['date'], errors='coerce')
df_model.sort_values(by=['cid', 'date'], inplace=True)

# %%
# Retirer les lignes où Quality_Flag est False
df_model = df_model[df_model['QUALITY_FLAG'] == True]

# (FACULTATIF) Exclure les banques
# df_model = df_model[df_model['industry'] != 'Banks']

# %%
# Définir la liste des colonnes "ratios" qu’on veut conserver
# ---------------------------
ratio_keywords = [
    '_on_assets_ratio',
    '_on_rev_ratio',
    '_on_tot_cap_ratio'
]

# On va chercher toutes les colonnes qui contiennent l’un de ces substrings
ratio_cols = [
    col for col in df_model.columns
    if any(rk in col for rk in ratio_keywords)
]

# ---------------------------
# Définir les colonnes minimales qu’on veut absolument
# ---------------------------
mandatory_cols = ['date', 'cid', 'target_net_income']

# ---------------------------
# Construire la liste finale des colonnes à garder
# ---------------------------
columns_to_keep = mandatory_cols + ratio_cols

# ---------------------------
# Créer le df_model_final avec seulement ces colonnes
# ---------------------------
df_model_final = df_model[columns_to_keep].copy()

# ---------------------------
# (Optionnel) trier par (cid, date)
# ---------------------------
df_model_final.sort_values(by=['cid', 'date'], inplace=True)

# %%
# Compter le nombre total de NaN dans tout le DataFrame
total_nan = df_model_final.isna().sum().sum()
print(f"Nombre total de valeurs NaN dans df_model_final : {total_nan}")

# Retirer les lignes qui contiennent AU MOINS un NaN
df_model_final.dropna(inplace=True)

# Vérifier à nouveau qu’il n’y a plus de NaN
total_nan_apres = df_model_final.isna().sum().sum()
print(f"Nombre total de valeurs NaN après suppression : {total_nan_apres}")
# Out:
# Nombre total de valeurs NaN dans df_model_final : 124606
# Nombre total de valeurs NaN après suppression : 0

# %% [markdown]
# ## DF Test (5 ans seulement), pour tester rapidement la fonciton

# %%
# Date la plus récente du DataFrame
max_date = df_model_final['date'].max()

# Date de coupure (5 ans avant)
cutoff_date = max_date - pd.DateOffset(years=6)

# Filtrer pour ne garder que les 5 dernières années
df_test = df_model_final[df_model_final['date'] >= cutoff_date].copy()

print(df_test['date'].min(), df_test['date'].max())
print(df_test.shape)
# Out:
# 2018-09-20 00:00:00 2024-09-19 00:00:00
# (9362, 195)

# %% [markdown]
# ## Fonction Principale avec AutoML et Rolling Window

# %%
def pipeline_rolling_windows(data, date_col, target_col, train_years, val_years, test_years, buffer_months=0):
    """
    Pipeline direct pour la rolling window avec AutoML et cross-validation personnalisée.
    Ajoute les périodes dans le DataFrame final pour validation.
    """
    # Conversion de la colonne date
    data[date_col] = pd.to_datetime(data[date_col])
    start_date = data[date_col].min()
    end_date = data[date_col].max()

    predictions_all = []  # Liste pour stocker toutes les prédictions

    while start_date + relativedelta(years=train_years + val_years + test_years) <= end_date:
        # Définir les périodes
        train_end = start_date + relativedelta(years=train_years) - pd.Timedelta(days=1)
        tampon_1_end = train_end + relativedelta(months=buffer_months)
        val_start = tampon_1_end + pd.Timedelta(days=1)
        val_end = val_start + relativedelta(years=val_years) - pd.Timedelta(days=1)
        tampon_2_end = val_end + relativedelta(months=buffer_months)
        test_start = tampon_2_end + pd.Timedelta(days=1)
        test_end = test_start + relativedelta(years=test_years) - pd.Timedelta(days=1)

        # Filtrer les données
        train_data = data.loc[(data[date_col] >= start_date) & (data[date_col] <= train_end)]
        val_data = data.loc[(data[date_col] >= val_start) & (data[date_col] <= val_end)]
        test_data = data.loc[(data[date_col] >= test_start) & (data[date_col] <= test_end)]

        if len(train_data) == 0 or len(val_data) == 0 or len(test_data) == 0:
            print(f"Fenêtre {start_date.year}-{test_end.year} : données insuffisantes, sautée.")
            start_date += relativedelta(years=1)
            continue

        # Configurer et entraîner AutoML
        print(f"Fenêtre {start_date.year}-{test_end.year} : entraînement de AutoML...")
        automl = AutoML(mode="Perform", algorithms=["Xgboost"])
        custom_cv = [(train_data.index, val_data.index)]
        automl.fit(
            train_data.drop(columns=[target_col, date_col, 'cid']),
            train_data[target_col], cv=custom_cv
        )

        # Prédire sur le test set
        test_preds = test_data[[date_col, target_col]].copy()
        test_preds["predicted"] = automl.predict(test_data.drop(columns=[target_col, date_col, 'cid']))
        test_preds["window"] = f"{start_date.year}-{test_end.year}"
        test_preds["cid"] = test_data["cid"].values

        # Ajouter les périodes pour validation
        test_preds["train_start"] = start_date
        test_preds["train_end"] = train_end
        test_preds["tampon_1"] = tampon_1_end
        test_preds["val_start"] = val_start
        test_preds["val_end"] = val_end
        test_preds["tampon_2"] = tampon_2_end
        test_preds["test_start"] = test_start
        test_preds["test_end"] = test_end

        # Sauvegarder les prédictions
        predictions_all.append(test_preds)

        # Avancer la fenêtre
        start_date += relativedelta(years=1)

    predictions_df = pd.concat(predictions_all, ignore_index=True)
    return predictions_df

# %% [markdown]
# ## Appel de fonction

# %%
predictions_df = pipeline_rolling_windows(
    data=df_test, 
    date_col="date", 
    target_col="target_net_income", 
    train_years=2, 
    val_years=1, 
    test_years=1, 
    buffer_months=1
)
# Out:
# Fenêtre 2018-2022 : entraînement de AutoML...
# AutoML directory: AutoML_1
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Xgboost']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'ensemble']
# Skip simple_algorithms because no parameters were generated.
# * Step default_algorithms will try to check up to 1 model
# 1_Default_Xgboost rmse 373.079877 trained in 11.51 seconds (1-sample predict time 0.035 seconds)
# * Step not_so_random will try to check up to 4 models
# 2_Xgboost rmse 373.297357 trained in 9.9 seconds (1-sample predict time 0.0349 seconds)
# 3_Xgboost rmse 369.928487 trained in 10.17 seconds (1-sample predict time 0.0352 seconds)
# 4_Xgboost rmse 371.726329 trained in 6.18 seconds (1-sample predict time 0.0351 seconds)
# 5_Xgboost rmse 376.126961 trained in 10.58 seconds (1-sample predict time 0.0354 seconds)
# * Step golden_features will try to check up to 3 models
# None 18
# Add Golden Feature: E_G_cash_investing_on_tot_cap_ratio_ratio_E_G_ammor_intangibles_on_rev_ratio
# Add Golden Feature: E_G_int_div_income_on_assets_ratio_ratio_E_G_quick_ratio_on_rev_ratio
# Add Golden Feature: E_G_receivables_on_tot_cap_ratio_ratio_E_G_ammor_intangibles_on_rev_ratio
# Add Golden Feature: E_G_int_div_income_on_tot_cap_ratio_multiply_E_G_pref_div_on_rev_ratio
# Add Golden Feature: E_G_pref_div_on_tot_cap_ratio_multiply_E_G_int_div_income_on_rev_ratio
# Add Golden Feature: E_G_pref_div_on_rev_ratio_multiply_E_G_int_div_income_on_assets_ratio
# Add Golden Feature: E_G_int_div_income_on_rev_ratio_multiply_E_G_pref_div_on_assets_ratio
# Add Golden Feature: E_G_compre_income_on_assets_ratio_ratio_E_G_quick_ratio_on_tot_cap_ratio
# Add Golden Feature: E_G_unusual_items_on_tot_cap_ratio_ratio_E_G_cost_borrowing_on_rev_ratio
# Add Golden Feature: E_G_operating_income_on_rev_ratio_ratio_E_G_quick_ratio_on_assets_ratio
# Add Golden Feature: E_G_ebit_on_rev_ratio_ratio_E_G_quick_ratio_on_assets_ratio
# Add Golden Feature: E_G_pref_equity_on_rev_ratio_ratio_E_G_ebit_on_assets_ratio
# Add Golden Feature: E_G_assets_gro_five_on_rev_ratio_ratio_E_G_cash_acquisitions_on_assets_ratio
# Add Golden Feature: E_G_ebt_x_unusual_on_assets_ratio_ratio_E_G_pref_div_on_tot_cap_ratio
# Add Golden Feature: E_G_pref_div_on_tot_cap_ratio_ratio_E_G_ebt_x_unusual_on_assets_ratio
# Add Golden Feature: E_G_ammor_intangibles_on_rev_ratio_ratio_E_G_net_debt_on_tot_cap_ratio
# Add Golden Feature: E_G_shares_out_on_tot_cap_ratio_sum_E_G_cash_investing_on_tot_cap_ratio
# Add Golden Feature: E_G_interest_expense_on_rev_ratio_sum_E_G_unusual_items_on_assets_ratio
# Created 18 Golden Features in 6.35 seconds.
# 3_Xgboost_GoldenFeatures rmse 371.867614 trained in 13.47 seconds (1-sample predict time 0.0558 seconds)
# 4_Xgboost_GoldenFeatures rmse 367.972894 trained in 7.66 seconds (1-sample predict time 0.0556 seconds)
# 1_Default_Xgboost_GoldenFeatures rmse 367.086571 trained in 6.24 seconds (1-sample predict time 0.0557 seconds)
# * Step insert_random_feature will try to check up to 1 model
# 1_Default_Xgboost_GoldenFeatures_RandomFeature rmse 366.688729 trained in 6.25 seconds (1-sample predict time 0.0568 seconds)
# Drop features ['E_G_total_div_on_assets_ratio', 'E_G_cogs_on_rev_ratio', 'E_G_total_liabilities_on_tot_cap_ratio', 'E_G_net_property_on_tot_cap_ratio', 'E_G_restructuring_charges_on_assets_ratio', 'E_G_quick_ratio_on_rev_ratio', 'E_G_unusual_items_on_tot_cap_ratio', 'E_G_net_income_inc_on_tot_cap_ratio', 'E_G_tangible_book_on_tot_cap_ratio', 'E_G_payables_on_assets_ratio', 'E_G_cost_borrowing_on_assets_ratio', 'E_G_effective_tax_rate_on_assets_ratio', 'E_G_int_div_income_on_assets_ratio', 'E_G_restructuring_charges_on_tot_cap_ratio', 'E_G_net_income_inc_on_rev_ratio', 'E_G_total_liabilities_on_assets_ratio', 'E_G_shares_out_on_assets_ratio', 'E_G_asset_writedown_on_tot_cap_ratio', 'E_G_quick_ratio_on_assets_ratio', 'E_G_cash_investing_on_tot_cap_ratio_ratio_E_G_ammor_intangibles_on_rev_ratio', 'E_G_net_debt_on_rev_ratio', 'E_G_sga_on_assets_ratio', 'E_G_assets_gro_five_on_rev_ratio', 'E_G_sga_on_rev_ratio', 'E_G_total_intangibles_on_assets_ratio', 'E_G_net_property_on_assets_ratio', 'E_G_unusual_items_on_rev_ratio', 'E_G_int_div_income_on_tot_cap_ratio', 'E_G_r_d_on_assets_ratio', 'E_G_net_debt_on_tot_cap_ratio', 'E_G_cash_investing_on_tot_cap_ratio', 'E_G_total_debt_on_rev_ratio', 'E_G_net_inc_gro_five_on_tot_cap_ratio', 'E_G_ammor_intangibles_on_rev_ratio', 'E_G_ebt_x_unusual_on_tot_cap_ratio', 'E_G_rev_gro_five_on_tot_cap_ratio', 'E_G_receivables_on_tot_cap_ratio_ratio_E_G_ammor_intangibles_on_rev_ratio', 'E_G_ebt_x_unusual_on_assets_ratio', 'E_G_rev_gro_five_on_assets_ratio', 'E_G_common_equity_on_assets_ratio', 'E_G_interest_expense_on_rev_ratio_sum_E_G_unusual_items_on_assets_ratio', 'E_G_current_liabilities_on_rev_ratio', 'E_G_ammor_intangibles_on_assets_ratio', 'E_G_repurchase_stock_on_rev_ratio', 'E_G_ammor_intangibles_on_rev_ratio_ratio_E_G_net_debt_on_tot_cap_ratio', 'E_G_receivables_on_rev_ratio', 'E_G_cogs_on_tot_cap_ratio', 'E_G_ebt_x_unusual_on_rev_ratio', 'E_G_ammor_intangibles_on_tot_cap_ratio', 'E_G_working_cap_on_rev_ratio', 'E_G_def_tax_liability_on_rev_ratio', 'E_G_net_debt_on_assets_ratio', 'E_G_effective_tax_rate_on_tot_cap_ratio', 'E_G_cost_borrowing_on_tot_cap_ratio', 'E_G_cash_equi_on_rev_ratio', 'E_G_pref_div_on_tot_cap_ratio', 'E_G_norm_net_inc_on_rev_ratio', 'E_G_def_tax_assets_on_rev_ratio', 'E_G_effective_tax_rate_on_rev_ratio', 'E_G_total_div_on_tot_cap_ratio', 'E_G_minority_int_on_rev_ratio', 'E_G_ebitda_on_tot_cap_ratio', 'E_G_ebit_on_tot_cap_ratio', 'E_G_ebit_on_rev_ratio_ratio_E_G_quick_ratio_on_assets_ratio', 'E_G_gross_profit_on_assets_ratio', 'E_G_payables_on_rev_ratio', 'E_G_cash_investing_on_rev_ratio', 'E_G_pref_equity_on_rev_ratio_ratio_E_G_ebit_on_assets_ratio', 'E_G_total_liabilities_on_rev_ratio', 'E_G_rev_gro_five_on_rev_ratio', 'E_G_pref_div_on_assets_ratio', 'E_G_operating_income_on_rev_ratio', 'E_G_pref_equity_on_tot_cap_ratio', 'E_G_total_capital_on_rev_ratio', 'E_G_total_assets_on_rev_ratio', 'E_G_compre_income_on_rev_ratio', 'E_G_compre_income_on_tot_cap_ratio', 'E_G_total_capital_on_assets_ratio', 'E_G_asset_writedown_on_rev_ratio', 'E_G_net_property_on_rev_ratio', 'E_G_current_assets_on_assets_ratio', 'E_G_working_cap_on_tot_cap_ratio', 'E_G_payables_on_tot_cap_ratio', 'E_G_ebitda_on_rev_ratio', 'E_G_pref_div_on_rev_ratio_multiply_E_G_int_div_income_on_assets_ratio', 'E_G_minority_int_on_tot_cap_ratio', 'random_feature', 'E_G_operating_income_on_assets_ratio', 'E_G_capex_on_rev_ratio', 'E_G_issuance_stock_on_tot_cap_ratio', 'E_G_norm_net_inc_on_tot_cap_ratio', 'E_G_total_assets_on_tot_cap_ratio', 'E_G_ebit_on_assets_ratio', 'E_G_pref_div_on_rev_ratio', 'E_G_total_debt_on_tot_cap_ratio', 'E_G_inventory_on_tot_cap_ratio', 'E_G_tangible_book_on_rev_ratio', 'E_G_divestitures_on_rev_ratio', 'E_G_current_assets_on_rev_ratio', 'E_G_divestitures_on_assets_ratio', 'E_G_def_tax_assets_on_assets_ratio', 'E_G_gross_profit_on_rev_ratio', 'E_G_other_expenses_on_tot_cap_ratio', 'E_G_r_d_on_rev_ratio', 'E_G_total_revenues_on_tot_cap_ratio', 'E_G_norm_net_inc_on_assets_ratio', 'E_G_r_d_on_ ...
# * Step features_selection will try to check up to 1 model
# 1_Default_Xgboost_GoldenFeatures_SelectedFeatures rmse 361.527872 trained in 2.07 seconds (1-sample predict time 0.0246 seconds)
# * Step hill_climbing_1 will try to check up to 4 models
# 6_Xgboost_GoldenFeatures_SelectedFeatures rmse 365.234167 trained in 2.78 seconds (1-sample predict time 0.0249 seconds)
# 7_Xgboost_GoldenFeatures_SelectedFeatures rmse 360.918863 trained in 2.03 seconds (1-sample predict time 0.0249 seconds)
# 8_Xgboost_GoldenFeatures rmse 364.466138 trained in 7.09 seconds (1-sample predict time 0.0562 seconds)
# 9_Xgboost_GoldenFeatures rmse 364.05912 trained in 5.82 seconds (1-sample predict time 0.0564 seconds)
# * Step hill_climbing_2 will try to check up to 2 models
# 10_Xgboost_GoldenFeatures_SelectedFeatures rmse 362.730609 trained in 2.61 seconds (1-sample predict time 0.0253 seconds)
# 11_Xgboost_GoldenFeatures_SelectedFeatures rmse 364.954657 trained in 2.51 seconds (1-sample predict time 0.0247 seconds)
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 353.581379 trained in 0.17 seconds (1-sample predict time 0.1612 seconds)
# AutoML fit time: 117.4 seconds
# AutoML best model: Ensemble
# Fenêtre 2019-2023 : entraînement de AutoML...
# AutoML directory: AutoML_2
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Xgboost']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'ensemble']
# Skip simple_algorithms because no parameters were generated.
# * Step default_algorithms will try to check up to 1 model
# 1_Default_Xgboost rmse 390.226835 trained in 18.08 seconds (1-sample predict time 0.0408 seconds)
# * Step not_so_random will try to check up to 4 models
# 2_Xgboost rmse 384.485536 trained in 19.86 seconds (1-sample predict time 0.0373 seconds)
# 3_Xgboost rmse 390.293761 trained in 12.76 seconds (1-sample predict time 0.0367 seconds)
# 4_Xgboost rmse 390.730429 trained in 12.79 seconds (1-sample predict time 0.038 seconds)
# 5_Xgboost rmse 401.614861 trained in 10.27 seconds (1-sample predict time 0.0361 seconds)
# * Step golden_features will try to check up to 3 models
# None 18
# Add Golden Feature: E_G_total_intangibles_on_assets_ratio_ratio_E_G_repurchase_stock_on_rev_ratio
# Add Golden Feature: E_G_cash_acquisitions_on_rev_ratio_multiply_E_G_divestitures_on_assets_ratio
# Add Golden Feature: E_G_divestitures_on_rev_ratio_multiply_E_G_cash_acquisitions_on_assets_ratio
# Add Golden Feature: E_G_total_capital_on_rev_ratio_multiply_E_G_repurchase_stock_on_assets_ratio
# Add Golden Feature: E_G_repurchase_stock_on_assets_ratio_ratio_E_G_total_revenues_on_tot_cap_ratio
# Add Golden Feature: E_G_repurchase_stock_on_rev_ratio_ratio_E_G_total_assets_on_tot_cap_ratio
# Add Golden Feature: E_G_repurchase_stock_on_rev_ratio_multiply_E_G_total_capital_on_assets_ratio
# Add Golden Feature: E_G_effective_tax_rate_on_tot_cap_ratio_ratio_E_G_total_intangibles_on_assets_ratio
# Add Golden Feature: E_G_assets_gro_five_on_assets_ratio_ratio_E_G_other_expenses_on_tot_cap_ratio
# Add Golden Feature: E_G_inventory_on_assets_ratio_ratio_E_G_working_cap_on_rev_ratio
# Add Golden Feature: E_G_retained_earnings_on_rev_ratio_multiply_E_G_pref_div_on_assets_ratio
# Add Golden Feature: E_G_pref_div_on_rev_ratio_multiply_E_G_retained_earnings_on_assets_ratio
# Add Golden Feature: E_G_effective_tax_rate_on_rev_ratio_ratio_E_G_divestitures_on_rev_ratio
# Add Golden Feature: E_G_effective_tax_rate_on_tot_cap_ratio_ratio_E_G_divestitures_on_tot_cap_ratio
# Add Golden Feature: E_G_effective_tax_rate_on_assets_ratio_ratio_E_G_divestitures_on_assets_ratio
# Add Golden Feature: E_G_other_expenses_on_tot_cap_ratio_sum_E_G_receivables_on_assets_ratio
# Add Golden Feature: E_G_current_liabilities_on_rev_ratio_ratio_E_G_cash_financing_on_assets_ratio
# Add Golden Feature: E_G_repurchase_stock_on_assets_ratio_multiply_E_G_other_expenses_on_assets_ratio
# Created 18 Golden Features in 6.3 seconds.
# 2_Xgboost_GoldenFeatures rmse 372.506381 trained in 31.28 seconds (1-sample predict time 0.0635 seconds)
# 1_Default_Xgboost_GoldenFeatures rmse 387.578898 trained in 19.76 seconds (1-sample predict time 0.0623 seconds)
# 3_Xgboost_GoldenFeatures rmse 384.02599 trained in 15.43 seconds (1-sample predict time 0.0595 seconds)
# * Step insert_random_feature will try to check up to 1 model
# 2_Xgboost_GoldenFeatures_RandomFeature rmse 375.493994 trained in 20.23 seconds (1-sample predict time 0.0618 seconds)
# Drop features ['E_G_pref_equity_on_assets_ratio', 'E_G_total_liabilities_on_rev_ratio', 'E_G_tax_expense_on_tot_cap_ratio', 'E_G_payables_on_rev_ratio', 'E_G_cash_acquisitions_on_assets_ratio', 'E_G_cogs_on_tot_cap_ratio', 'E_G_ops_expenses_on_tot_cap_ratio', 'E_G_norm_net_inc_on_tot_cap_ratio', 'E_G_sga_on_rev_ratio', 'E_G_working_cap_on_assets_ratio', 'E_G_current_assets_on_assets_ratio', 'E_G_net_income_inc_on_assets_ratio', 'E_G_cash_financing_on_tot_cap_ratio', 'E_G_rev_gro_five_on_assets_ratio', 'E_G_total_div_on_assets_ratio', 'E_G_tangible_book_on_rev_ratio', 'E_G_cogs_on_assets_ratio', 'E_G_ammor_intangibles_on_rev_ratio', 'E_G_cash_equi_on_assets_ratio', 'E_G_cash_operations_on_assets_ratio', 'E_G_cash_acquisitions_on_tot_cap_ratio', 'E_G_shares_out_on_rev_ratio', 'E_G_sga_on_assets_ratio', 'E_G_retained_earnings_on_assets_ratio', 'E_G_divestitures_on_tot_cap_ratio', 'E_G_cash_operations_on_rev_ratio', 'E_G_net_inc_gro_five_on_assets_ratio', 'E_G_gross_profit_on_assets_ratio', 'E_G_cash_investing_on_rev_ratio', 'E_G_cash_financing_on_assets_ratio', 'E_G_total_intangibles_on_assets_ratio_ratio_E_G_repurchase_stock_on_rev_ratio', 'E_G_def_tax_assets_on_rev_ratio', 'E_G_working_cap_on_tot_cap_ratio', 'E_G_net_debt_on_assets_ratio', 'E_G_ebt_x_unusual_on_assets_ratio', 'E_G_other_expenses_on_tot_cap_ratio_sum_E_G_receivables_on_assets_ratio', 'E_G_pref_equity_on_tot_cap_ratio', 'random_feature', 'E_G_tax_expense_on_assets_ratio', 'E_G_inventory_on_rev_ratio', 'E_G_gross_profit_on_rev_ratio', 'E_G_interest_expense_on_assets_ratio', 'E_G_asset_writedown_on_rev_ratio', 'E_G_restructuring_charges_on_assets_ratio', 'E_G_ebit_on_tot_cap_ratio', 'E_G_compre_income_on_tot_cap_ratio', 'E_G_cash_operations_on_tot_cap_ratio', 'E_G_total_div_on_rev_ratio', 'E_G_norm_net_inc_on_assets_ratio', 'E_G_assets_gro_five_on_rev_ratio', 'E_G_net_income_inc_on_rev_ratio', 'E_G_compre_income_on_rev_ratio', 'E_G_capex_on_rev_ratio', 'E_G_asset_writedown_on_assets_ratio', 'E_G_total_capital_on_assets_ratio', 'E_G_total_div_on_tot_cap_ratio', 'E_G_current_assets_on_tot_cap_ratio', 'E_G_interest_expense_on_tot_cap_ratio', 'E_G_effective_tax_rate_on_tot_cap_ratio', 'E_G_total_debt_on_assets_ratio', 'E_G_restructuring_charges_on_rev_ratio', 'E_G_assets_gro_five_on_assets_ratio', 'E_G_cash_financing_on_rev_ratio', 'E_G_net_inc_gro_five_on_tot_cap_ratio', 'E_G_divestitures_on_assets_ratio', 'E_G_working_cap_on_rev_ratio', 'E_G_total_assets_on_rev_ratio', 'E_G_operating_income_on_rev_ratio', 'E_G_issuance_stock_on_assets_ratio', 'E_G_int_div_income_on_tot_cap_ratio', 'E_G_minority_int_on_rev_ratio', 'E_G_issuance_stock_on_rev_ratio', 'E_G_net_inc_gro_five_on_rev_ratio', 'E_G_operating_income_on_tot_cap_ratio', 'E_G_total_revenues_on_tot_cap_ratio', 'E_G_total_liabilities_on_assets_ratio', 'E_G_r_d_on_assets_ratio', 'E_G_current_liabilities_on_assets_ratio', 'E_G_issuance_stock_on_tot_cap_ratio', 'E_G_norm_net_inc_on_rev_ratio', 'E_G_compre_income_on_assets_ratio', 'E_G_common_equity_on_tot_cap_ratio', 'E_G_receivables_on_tot_cap_ratio', 'E_G_pref_div_on_tot_cap_ratio', 'E_G_minority_int_on_tot_cap_ratio', 'E_G_total_expenses_on_rev_ratio', 'E_G_effective_tax_rate_on_rev_ratio_ratio_E_G_divestitures_on_rev_ratio', 'E_G_provision_loan_on_assets_ratio', 'E_G_core_banks_on_assets_ratio', 'E_G_repurchase_stock_on_rev_ratio_ratio_E_G_total_assets_on_tot_cap_ratio', 'E_G_divestitures_on_rev_ratio_multiply_E_G_cash_acquisitions_on_assets_ratio', 'E_G_core_banks_on_rev_ratio', 'E_G_repurchase_stock_on_rev_ratio_multiply_E_G_total_capital_on_assets_ratio', 'E_G_total_expenses_on_tot_cap_ratio', 'E_G_repurchase_stock_on_assets_ratio_ratio_E_G_total_revenues_on_tot_cap_ratio', 'E_G_effective_tax_rate_on_assets_ratio_ratio_E_G_divestitures_on_assets_ratio', 'E_G_provision_loan_on_tot_cap_ratio', 'E_G_pref_div_on_rev_ratio_multiply_E_G_retained_earnings_on_assets_ratio', 'E_G_core_banks_on_tot_cap_ratio', 'E_G_provision_loan_on_rev_ratio', 'E_G_effective_tax_rate_on_ ...
# * Step features_selection will try to check up to 1 model
# 2_Xgboost_GoldenFeatures_SelectedFeatures rmse 371.494697 trained in 6.86 seconds (1-sample predict time 0.0326 seconds)
# * Step hill_climbing_1 will try to check up to 4 models
# 6_Xgboost_GoldenFeatures_SelectedFeatures rmse 374.770575 trained in 8.6 seconds (1-sample predict time 0.0332 seconds)
# 7_Xgboost_GoldenFeatures_SelectedFeatures rmse 374.711562 trained in 7.01 seconds (1-sample predict time 0.0327 seconds)
# 8_Xgboost_GoldenFeatures rmse 374.482696 trained in 20.09 seconds (1-sample predict time 0.0594 seconds)
# 9_Xgboost_GoldenFeatures rmse 379.910525 trained in 12.36 seconds (1-sample predict time 0.0586 seconds)
# * Step hill_climbing_2 will try to check up to 2 models
# 10_Xgboost_GoldenFeatures_SelectedFeatures rmse 369.895338 trained in 8.0 seconds (1-sample predict time 0.0297 seconds)
# 11_Xgboost_GoldenFeatures rmse 378.417902 trained in 16.23 seconds (1-sample predict time 0.0569 seconds)
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 367.32517 trained in 0.17 seconds (1-sample predict time 0.1835 seconds)
# AutoML fit time: 253.48 seconds
# AutoML best model: Ensemble

# %%
predictions_df.to_csv("df_can_test.csv", index=False)

# %%
# Générer des valeurs aléatoires entre -1 et 1
np.random.seed(42)  # Fixer la graine pour la reproductibilité
predictions_df['predicted'] = np.random.uniform(-1, 1, size=len(predictions_df))  # Remplace 'n' par la taille désirée

# %%
# Assure que les colonnes 'date' sont au bon format datetime dans les deux DataFrames
predictions_df['date'] = pd.to_datetime(predictions_df['date'])
df_canada['date'] = pd.to_datetime(df_canada['date'])

# Faire la jointure sur 'cid' et 'date'
merged_df = predictions_df.merge(df_canada[['cid', 'date', 'return_1q']], on=['cid', 'date'], how='left')

# %%
merged_df
# Out:
#            date  target_net_income  predicted     window        cid  \
# 0    2022-02-17           -240.562  -0.250920  2018-2022    MISSING
# 1    2022-03-04           -240.562   0.901429  2018-2022    MISSING
# 2    2022-04-28             49.957   0.463988  2018-2022    MISSING
# 3    2022-07-28           -322.760   0.197317  2018-2022    MISSING
# 4    2022-10-27            210.290  -0.687963  2018-2022    MISSING
# ...         ...                ...        ...        ...        ...
# 3063 2023-09-12              2.276   0.247298  2019-2023  SP-278234
# 3064 2023-03-21             -6.998   0.297010  2019-2023  SP-329579
# 3065 2023-05-15            116.437  -0.465196  2019-2023  SP-329579
# 3066 2023-08-08             66.105  -0.969779  2019-2023  SP-329579
# 3067 2023-11-06            -40.530   0.930031  2019-2023  SP-329579
#
#      train_start  train_end   tampon_1  val_start    val_end   tampon_2  \
# 0     2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1     2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 2     2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 3     2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 4     2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# ...          ...        ...        ...        ...        ...        ...
# 3063  2019-09-20 2021-09-19 2021-10-19 2021-10-20 2022-10-19 2022-11-19
# 3064  2019-09-20 2021-09-19 2021-10-19 2021-10-20 2022-10-19 2022-11-19
# 3065  2019-09-20 2021-09-19 2021-10-19 2021-10-20 2022-10-19 2022-11-19
# 3066  2019-09-20 2021-09-19 2021-10-19 2021-10-20 2022-10-19 2022-11-19
# 3067  2019-09-20 2021-09-19 2021-10-19 2021-10-20 2022-10-19 2022-11-19
#
#      test_start   test_end  return_1q
# 0    2021-11-20 2022-11-19        NaN
# 1    2021-11-20 2022-11-19        NaN
# 2    2021-11-20 2022-11-19        NaN
# 3    2021-11-20 2022-11-19        NaN
# 4    2021-11-20 2022-11-19        NaN
# ...         ...        ...        ...
# 3063 2022-11-20 2023-11-19  -0.131886
# 3064 2022-11-20 2023-11-19   1.296319
# 3065 2022-11-20 2023-11-19   0.532269
# 3066 2022-11-20 2023-11-19  -0.231280
# 3067 2022-11-20 2023-11-19   2.025858
#
# [3068 rows x 14 columns]

# %%
# Extraire l'année à partir de la colonne 'date'
merged_df['year'] = merged_df['date'].dt.year

# %%
merged_df['year']
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 3063    2023
# 3064    2023
# 3065    2023
# 3066    2023
# 3067    2023
# Name: year, Length: 3068, dtype: int32

# %%
# Voir les valeurs uniques et leur compte dans la colonne 'cid'
value_counts = merged_df['year'].value_counts()
print(value_counts)
# Out:
# year
# 2022    1575
# 2023    1466
# 2021      27
# Name: count, dtype: int64

# %%
df_2021 = merged_df[merged_df['year'] == 2021].copy()
# Out:
#            date  target_net_income  predicted     window        cid  \
# 156  2021-11-23         -72.000000   0.344271  2018-2022  SP-011443
# 167  2021-12-16          -4.732000  -0.626963  2018-2022  SP-013252
# 205  2021-12-09          27.100000  -0.981606  2018-2022  SP-014312
# 277  2021-12-09          -9.300000   0.299928  2018-2022  SP-015083
# 281  2021-12-14          -5.313006  -0.324010  2018-2022  SP-015096
# 393  2021-12-01          -8.180000   0.552826  2018-2022  SP-020392
# 394  2021-12-02          -8.180000  -0.318393  2018-2022  SP-020392
# 463  2021-11-23          33.031000   0.166738  2018-2022  SP-021577
# 471  2021-12-20          16.200000   0.939758  2018-2022  SP-021894
# 512  2021-12-08           2.521000   0.865457  2018-2022  SP-023994
# 620  2021-11-24           1.822000  -0.630958  2018-2022  SP-028862
# 680  2021-12-14        -690.046000   0.634144  2018-2022  SP-030664
# 705  2021-12-02           7.143000   0.979920  2018-2022  SP-031602
# 884  2021-12-16           0.955000   0.599832  2018-2022  SP-063476
# 900  2021-12-08          -1.343000  -0.584227  2018-2022  SP-064624
# 908  2021-11-23         138.900000  -0.481153  2018-2022  SP-064655
# 912  2021-12-09          -4.335000   0.248298  2018-2022  SP-064686
# 948  2021-12-21         459.000000   0.747780  2018-2022  SP-065986
# 949  2021-12-22         459.000000   0.194826  2018-2022  SP-065986
# 960  2021-12-01           1.991000  -0.834403  2018-2022  SP-066326
# 1102 2021-11-25           5.268000   0.767572  2018-2022  SP-111003
# 1116 2021-12-01          -0.907000  -0.817026  2018-2022  SP-112820
# 1193 2021-11-25           3.453000   0.241831  2018-2022  SP-130638
# 1267 2021-12-07          17.691000  -0.040122  2018-2022  SP-155613
# 1322 2021-12-01         -54.900000   0.743567  2018-2022  SP-162870
# 1485 2021-12-08          46.064000  -0.267077  2018-2022  SP-183683
# 1568 2021-12-08          10.978000   0.247719  2018-2022  SP-278234
#
#      train_start  train_end   tampon_1  val_start    val_end   tampon_2  \
# 156   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 167   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 205   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 277   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 281   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 393   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 394   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 463   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 471   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 512   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 620   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 680   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 705   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 884   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 900   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 908   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 912   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 948   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 949   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 960   2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1102  2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1116  2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1193  2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1267  2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1322  2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1485  2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
# 1568  2018-09-20 2020-09-19 2020-10-19 2020-10-20 2021-10-19 2021-11-19
#
#      test_start   test_end  return_1q  year
# 156  2021-11-20 2022-11-19   0.060325  2021
# 167  2021-11-20 2022-11-19   0.139527  2021
# 205  2021-11-20 2022-11-19   0.000565  2021
# 277  2021-11-20 2022-11-19   0.017960  2021
# 281  2021-11-20 2022-11-19  -0.149961  2021
# 393  2021-11-20 2022-11-19   0.032507  2021
# 394  2021-11-20 2022-11-19   0.032507  2021
# 463  2021-11-20 2022-11-19  -0.218407  2021
# 471  2021-11-20 2022-11-19   0.094630  2021
# 512  2021-11-20 2022-11-19   0.009628  2021
# 620  2021-11-20 2022-11-19  -0.007769  2021
# 680  2021-11-20 2022-11-19  -0.692010  2021
# 705  2021-11-20 2022-11-19  -0.128745  2021
# 884  2021-11-20 2022-11-19  -0.221493  2021
# 900  2021-11-20 2022-11-19   0.083959  2021
# 908  2021-11-20 2022-11-19   0.001498  2021
# 912  2021-11-20 2022-11-19   0.042539  2021
# 948  2021-11-20 2022-11-19  -0.317403  2021
# 949  2021-11-20 2022-11-19  -0.317403  2021
# 960  2021-11-20 2022-11-19  -0.148981  2021
# 1102 2021-11-20 2022-11-19   0.096017  2021
# 1116 2021-11-20 2022-11-19  -0.265604  2021
# 1193 2021-11-20 2022-11-19   0.089572  2021
# 1267 2021-11-20 2022-11-19   0.149110  2021
# 1322 2021-11-20 2022-11-19  -0.095682  2021
# 1485 2021-11-20 2022-11-19   0.093514  2021
# 1568 2021-11-20 2022-11-19  -0.119154  2021

# %%
def create_weighted_portfolios(predictions_df, df_canada, return_col, lower_threshold=0.4, upper_threshold=0.6):
    """
    Crée un portefeuille pondéré basé sur les prédictions et calcule les rendements pondérés par année.
    
    Args:
    - predictions_df (pd.DataFrame): DataFrame contenant les prédictions et les identifiants 'cid'.
    - df_canada (pd.DataFrame): DataFrame contenant les rendements futurs et les identifiants 'cid'.
    - return_col (str): Nom de la colonne des rendements futurs dans df_canada.
    - lower_threshold (float): Seuil inférieur pour les positions courtes.
    - upper_threshold (float): Seuil supérieur pour les positions longues.
    
    Returns:
    - result_df (pd.DataFrame): DataFrame contenant les rendements pondérés des portefeuilles par année.
    """
    # Joindre les deux DataFrames sur 'cid' et 'date'
    merged_df = predictions_df.merge(df_canada[['cid', 'date', return_col]], on=['cid', 'date'], how='left')
    
    # Extraire l'année à partir de la colonne 'date'
    merged_df['year'] = merged_df['date'].dt.year
    
    # Initialiser une liste pour stocker les résultats
    results = []

    # Grouper par année
    for year, group in merged_df.groupby('year'):
        # Sélectionner les actions longues et courtes selon les seuils
        selected = group[(group['predicted'] > upper_threshold) | (group['predicted'] < lower_threshold)]
        
        if len(selected) > 0:
            # Attribuer des poids égaux à chaque action sélectionnée
            selected['weight'] = 1 / len(selected)
            
            # Calculer le rendement pondéré du portefeuille
            weighted_return = (selected['weight'] * selected[return_col]).sum()
            
            # Ajouter le résultat à la liste
            results.append({'year': year, 'weighted_return': weighted_return})
        else:
            # Si aucune action ne respecte les seuils, le rendement est NaN
            results.append({'year': year, 'weighted_return': float('nan')})

    # Convertir les résultats en DataFrame
    result_df = pd.DataFrame(results)
    
    return result_df

# %%
test_returns = create_weighted_portfolios(predictions_df, df_canada, 'return_1q', lower_threshold=0.5, upper_threshold=0.5)

# %%
test_returns
# Out:
#    year  weighted_return
# 0  2021        -0.064398
# 1  2022        -0.019383
# 2  2023         0.024381
